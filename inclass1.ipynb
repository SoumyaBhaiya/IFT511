# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("adult-1.data", header=None)
df #also try df[3]
# Out:
#        0                  1       2            3   4                    5   \
# 0      39          State-gov   77516    Bachelors  13        Never-married
# 1      50   Self-emp-not-inc   83311    Bachelors  13   Married-civ-spouse
# 2      38            Private  215646      HS-grad   9             Divorced
# 3      53            Private  234721         11th   7   Married-civ-spouse
# 4      28            Private  338409    Bachelors  13   Married-civ-spouse
# ...    ..                ...     ...          ...  ..                  ...
# 32556  27            Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32557  40            Private  154374      HS-grad   9   Married-civ-spouse
# 32558  58            Private  151910      HS-grad   9              Widowed
# 32559  22            Private  201490      HS-grad   9        Never-married
# 32560  52       Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
# ...

# %%
df.iloc[0] #it will give the location of the first heading. REMEMBER THAT THE INDEXING STARTS FROM THE 0TH
# Out:
# 0                 39
# 1          State-gov
# 2              77516
# 3          Bachelors
# 4                 13
# 5      Never-married
# 6       Adm-clerical
# 7      Not-in-family
# 8              White
# 9               Male
# 10              2174
# 11                 0
# 12                40
# 13     United-States
# 14             <=50K
# Name: 0, dtype: object

# %%
df[[0, 1, 3]]
# Out:
#         0                  1            3
# 0      39          State-gov    Bachelors
# 1      50   Self-emp-not-inc    Bachelors
# 2      38            Private      HS-grad
# 3      53            Private         11th
# 4      28            Private    Bachelors
# ...    ..                ...          ...
# 32556  27            Private   Assoc-acdm
# 32557  40            Private      HS-grad
# 32558  58            Private      HS-grad
# 32559  22            Private      HS-grad
# 32560  52       Self-emp-inc      HS-grad
#
# [32561 rows x 3 columns]

# %%
df[[0, 1, 3]].iloc[2] #the output of the specific entry of the observation at the 2nd index.
# Out:
# 0          38
# 1     Private
# 3     HS-grad
# Name: 2, dtype: object

# %%
df[df[0]>40] #filtering the 0th column of the df data frame to the people who are above 40 year old
#AGAIN REMEMBER THAT THE INDEXIN START FROM THE 0TH COLUMN.
# Out:
#        0                  1       2              3   4   \
# 1      50   Self-emp-not-inc   83311      Bachelors  13
# 3      53            Private  234721           11th   7
# 6      49            Private  160187            9th   5
# 7      52   Self-emp-not-inc  209642        HS-grad   9
# 9      42            Private  159449      Bachelors  13
# ...    ..                ...     ...            ...  ..
# 32550  43   Self-emp-not-inc   27242   Some-college  10
# 32552  43            Private   84661      Assoc-voc  11
# 32554  53            Private  321865        Masters  14
# 32558  58            Private  151910        HS-grad   9
# 32560  52       Self-emp-inc  287927        HS-grad   9
#
#                            5                   6               7       8   \
# 1          Married-civ-spouse     Exec-managerial         Husband   White
# 3          Married-civ-spouse   Handlers-cleaners         Husband   Black
# ...

# %%
df[(df[0]>40) & (df[3] == ' HS-grad')] #SEE FOR WHITE SPACES. SOMETIMES THAT DATASET HAVE WHITE SPACE AND OUR PANDAS WILL SEE THAT WHITE SPACE AS A PART OF OUR DATA

# df[(df[0]>40) & (df[3].isin([' HS-grad']))]
#THIS WILL WORK THE SAME. 


#REMEMBER: THAT IN THE .isin() WE NEED TO PASS THE LIST IF WE WANNA
# Out:
#        0                  1       2         3   4                    5   \
# 7      52   Self-emp-not-inc  209642   HS-grad   9   Married-civ-spouse
# 21     54            Private  302146   HS-grad   9            Separated
# 24     59            Private  109015   HS-grad   9             Divorced
# 29     49            Private  193366   HS-grad   9   Married-civ-spouse
# 43     49            Private   94638   HS-grad   9            Separated
# ...    ..                ...     ...       ...  ..                  ...
# 32541  41                  ?  202822   HS-grad   9            Separated
# 32542  72                  ?  129912   HS-grad   9   Married-civ-spouse
# 32547  43            Private  260761   HS-grad   9   Married-civ-spouse
# 32558  58            Private  151910   HS-grad   9              Widowed
# 32560  52       Self-emp-inc  287927   HS-grad   9   Married-civ-spouse
#
#                        6               7       8        9      10  11  12  \
# ...

# %%
df[(df[0]>40) & (df[3].isin([' HS-grad',' 9th', ' 10th', ' 11th', ' 12th']))]
# Out:
#        0                  1       2         3   4                       5   \
# 3      53            Private  234721      11th   7      Married-civ-spouse
# 6      49            Private  160187       9th   5   Married-spouse-absent
# 7      52   Self-emp-not-inc  209642   HS-grad   9      Married-civ-spouse
# 21     54            Private  302146   HS-grad   9               Separated
# 23     43            Private  117037      11th   7      Married-civ-spouse
# ...    ..                ...     ...       ...  ..                     ...
# 32541  41                  ?  202822   HS-grad   9               Separated
# 32542  72                  ?  129912   HS-grad   9      Married-civ-spouse
# 32547  43            Private  260761   HS-grad   9      Married-civ-spouse
# 32558  58            Private  151910   HS-grad   9                 Widowed
# 32560  52       Self-emp-inc  287927   HS-grad   9      Married-civ-spouse
#
# ...

# %%
df[3].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
df[1].value_counts()
# Out:
# 1
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
#CREATING SUBSET OF THE DATAFRAME

df2 = df[[1, 3, 5, 6, 7, 8, 9, 13, 14]]

# %%
df2[1].value_counts()
# Out:
# 1
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
df2[5].unique()
# Out:
# array([' Never-married', ' Married-civ-spouse', ' Divorced',
#        ' Married-spouse-absent', ' Separated', ' Married-AF-spouse',
#        ' Widowed'], dtype=object)
